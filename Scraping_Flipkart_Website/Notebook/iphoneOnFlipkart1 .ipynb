# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
url="https://www.flipkart.com/mobiles/pr?sid=tyy%2F4io&p%5B%5D=facets.brand%255B%255D%3DApple&p%5B%5D=facets.availability%255B%255D%3DExclude%2BOut%2Bof%2BStock&otracker=clp_metro_expandable_1_apple-categ-94e9d_iPhone_apple-products-store_90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite_wp1&fm=neo%2Fmerchandising&iid=M_4bfdfc9b-d56f-4867-a47e-b028ce8dea24_1.90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite&ppt=CLP&ppn=CLP%3Aapple-products-store&page=3"

# %%
page=urllib.request.urlopen(url)

# %%
soup=BeautifulSoup(page,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
#   <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
#   <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/bundle.f6bcfd.css" rel="stylesheet"/>
#   <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon">
#    <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#    <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
#    <!-- Appple Touch Icons -->
#    <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#    <link href="/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#    <link href="/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#    <link href="/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#    <link href="/apple-touch-icon-57x57.png" rel="apple-touch-icon"/>
#    <!-- Twitter Meta Data -->
#    <meta content="app" name="twitter:card"/>
#    <meta content="Shop for electronics, apparels &amp; more using our Flipkart app Free shipping &amp; COD." name="twitter:description"/>
#    <meta content="in" name="twitter:app:country"/>
#    <meta content="Flipkart" name="al:ios:app_name"/>
#    <meta content="742044692" name="al:ios:app_store_id"/>
#    <meta content="Flipkart" name="twitter:app:name:iphone"/>
#    <meta content="742044692" name="twitter:app:id:iphone"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:iphone"/>
#    <meta content="Flipkart" name="twitter:app:name:ipad"/>
#    <meta content="742044692" name="twitter:app:id:ipad"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:ipad"/>
#    <meta content="Flipkart" name="twitter:app:name:googleplay"/>
#    <meta content="com.flipkart.android" name="twitter:app:id:googleplay"/>
#    <meta content="http://dl.flipkart.com/dl/home?" name="twitter:app:url:googleplay"/>
#    <style>
#     #container {
# 			height: 100%;
# 		}
#    </style>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/manifest.ea14f058.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/vendor.a85fa617.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/app.73945956.js">
#    </script>
#    <script crossorigin="anonymous" defer="" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/Home.d1810d8a.js">
#    </script>
#    <title>
#     Mobile Price List | Compare Mobiles and Buy Online @ Flipkart
#    </title>
#    <meta content="Mobile Price List | Compare Mobiles and Buy Online @ Flipkart" name="og_title" property="og:title">
#     <meta content="Mobiles, Mobiles online,mobile price" name="Keywords">
#      <meta content="Buy Mobile by comparing prices of different mobile brands.Check specification and read user reviews to choose the best mobile phone at Flipkart." name="Description">
#       <link href="https://www.flipkart.com/mobile-phones-store" rel="canonical"/>
#       <meta content="https://www.flipkart.com/mobile-phones-store" name="og_url" property="og:url">
#        <meta content="69D68C6BA09AE39EB88946D69662CC31" name="msvalidate.01">
#         <script nonce="3158612960963832607">
#          (function(){
# 		if (window.BOOMR && window.BOOMR.version) { return; }
# 		var dom,doc,where,iframe = document.createElement("iframe"),win = window;
#
# 		function boomerangSaveLoadTime(e) {
# 			win.BOOMR_onload=(e && e.timeStamp) || new Date().getTime();
# 		}
# 		if (win.addEventListener) {
# 			win.addEventListener("load", boomerangSaveLoadTime, false);
# 		} else if (win.attachEvent) {
# 			win.attachEvent("onload", boomerangSaveLoadTime);
# 		}
#
# 		iframe.src = "about:blank";
# 		iframe.title = ""; iframe.role = "presentation";
# 		(iframe.frameElement || iframe).style.cssText = "width:0;height:0;border:0;display:none;";
# 		where = document.getElementsByTagName("script")[0];
# 		where.parentNode.insertBefore(iframe, where);
#
# 		try {
# 			doc = iframe.contentWindow.document;
# 		} catch(e) {
# 			dom = document.domain;
# 			iframe.src="javascript:var d=document.open();d.domain='"+dom+"';void(0);";
# 			doc = iframe.contentWindow.document;
# 		}
# 		doc.open()._l = function() {
# 			var js = this.createElement("script");
# 			if (dom) { this.domain = dom; }
# 			js.id = "boomr-if-as";
# 			js.src = "https://s.go-mpulse.net/boomerang/" + "7CG9W-7YHV7-M833G-G7KXE-KVD3B";
# 			BOOMR_lstart=new Date().getTime();
# 			this.body.appendChild(js);
# 		};
# 		doc.addEventListener('DOMContentLoaded', function () {
# 			doc._l();
# 		});
# 		doc.write('<body>');
# 		doc.close();
# 		})();
#         </script>
#         <!--[if IE 9 ]>
# 	<script nonce="3158612960963832607">
# 		window.browserVersion = 'IE9';
# 		document.documentElement.className += ' ie9';
# 	</script>
# 	<![endif]-->
#         <!--[if !IE]><!-->
#         <script nonce="3158612960963832607">
#          if (/*@cc_on!@*/false) {
# 			window.browserVersion = 'IE10';
# 			document.documentElement.className += ' ie10';
# 		}
#         </script>
#         <!--<![endif]-->
#         <script nonce="3158612960963832607">
#          !function(){if("PerformancePaintTiming" in window){var e=window.__perf={e:[]};e.o=new PerformanceObserver(function(n){e.e=e.e.concat(n.getEntries())});try{e.o.observe({entryTypes:["paint"]})}catch(e){}}}();
#         </script>
#         <script nonce="3158612960963832607">
#          if (requestAnimationFrame && performance && performance.mark) {
# 			requestAnimationFrame(function () {
# 				window.first_paint = performance.now();
# 				performance.mark("first_paint");
# 			});
# 		}
#         </script>
#         <script nonce="3158612960963832607">
#          var loadJS = function (url) {
# 			return new Promise(function (resolve, reject) {
# 				var ref = document.getElementsByTagName('script')[0];
# 				var script = document.createElement('script');
# 				script.setAttribute('src', url);
# 				script.setAttribute('type', 'text/javascript');
# 				script.setAttribute('async', true);
# 				script.setAttribute('defer', true);
# 				script.setAttribute('nonce', "3158612960963832607");
# 				script.onload = function (e) {
# 					resolve();
# 				};
# 				script.onerror = function (err) {
# 					reject(err);
# 				};
# 				ref.parentNode.insertBefore(script, ref);
# 			});
# 		};
#
# 		window.loadTMXScript = function (cb) {
# 			var tmxTransactionId = "fb5fb2cb-ec7c-4c00-a06a-c08448315b4d" || '';
# 			if (tmxTransactionId) {
# 				var url = "https://h.online-metrix.net/fp/tags.js?org_id=50wn6kz3&session_id=" + tmxTransactionId + "&pageid=checkout";
# 				if (document.querySelectorAll('script[src="' + url + '"]').length === 0) {
# 					loadJS(url).then(function () {
# 						cb && cb();
#           }).catch(_ => {})
# 				}
# 			}
# 		}
#         </script>
#         <link href="https://www.flipkart.com/mobiles/pr?sid=tyy%2F4io&amp;p%5B%5D=facets.brand%255B%255D%3DApple&amp;p%5B%5D=facets.availability%255B%255D%3DExclude%2BOut%2Bof%2BStock&amp;otracker=clp_metro_expandable_1_apple-categ-94e9d_iPhone_apple-products-store_90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite_wp1&amp;fm=neo%2Fmerchandising&amp;iid=M_4bfdfc9b-d56f-4867-a47e-b028ce8dea24_1.90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite&amp;ppt=CLP&amp;ppn=CLP%3Aapple-products-store&amp;page=2" id="prev-page-link-tag" rel="prev"/>
#         <link href="https://www.flipkart.com/mobiles/pr?sid=tyy%2F4io&amp;p%5B%5D=facets.brand%255B%255D%3DApple&amp;p%5B%5D=facets.availability%255B%255D%3DExclude%2BOut%2Bof%2BStock&amp;otracker=clp_metro_expandable_1_apple-categ-94e9d_iPhone_apple-products-store_90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite_wp1&amp;fm=neo%2Fmerchandising&amp;iid=M_4bfdfc9b-d56f-4867-a47e-b028ce8dea24_1.90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite&amp;ppt=CLP&amp;ppn=CLP%3Aapple-products-store&amp;page=4" id="next-page-link-tag" rel="next"/>
#         <link href="https://www.flipkart.com/amp/mobiles/pr?sid=tyy%2F4io&amp;p%5B%5D=facets.brand%255B%255D%3DApple&amp;p%5B%5D=facets.availability%255B%255D%3DExclude%2BOut%2Bof%2BStock&amp;otracker=clp_metro_expandable_1_apple-categ-94e9d_iPhone_apple-products-store_90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite_wp1&amp;fm=neo%2Fmerchandising&amp;iid=M_4bfdfc9b-d56f-4867-a47e-b028ce8dea24_1.90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite&amp;ppt=CLP&amp;ppn=CLP%3Aapple-products-store&amp;page=3" rel="amphtml"/>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </link>
#  </head>
#  <body>
#   <div id="container">
#    <div data-reactroot="">
#     <header class="CGBNf7">
#      <div class="_1tz-RS">
#       <div class="Y5-ZPI">
#        <div class="AsXM8z">
#         <div class="row _3XGGG6">
#          <a class="_2OJxl5" href="/">
#           <img alt="Flipkart" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" title="Flipkart" width="110"/>
#          </a>
#          <div class="_1NLCcM">
#           <form action="/search" class="_1WMLwI header-form-search" method="GET">
#            <div class="row">
#             <div class="col-11-12">
#              <div class="O8ZS_U">
#               <input autocomplete="off" class="LM6RPg" name="q" placeholder="Search for products, brands and more" title="Search for products, brands and more" type="text" value=""/>
#              </div>
#             </div>
#             <div class="col-1-12">
#              <button class="vh79eN" type="submit">
#               <svg class="" height="20px" viewbox="0 0 17 18" width="20px" xmlns="http://www.w3.org/2000/svg">
#                <g fill="#2874F1" fill-rule="evenodd">
#                 <path class="_2BhAHa" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203">
#                 </path>
#                 <path class="_2BhAHa" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467">
#                 </path>
#                </g>
#               </svg>
#              </button>
#             </div>
#             <input name="otracker" type="hidden" value="start"/>
#             <input name="as-show" type="hidden" value="off"/>
#             <input name="as" type="hidden" value="off"/>
#            </div>
#            <ul class="col-11-12 _1PBbw8">
#            </ul>
#           </form>
#          </div>
#          <div class="_1Wr4v5">
#           <div class="JvUE0p">
#            <div class="_1jJkOg">
#             <a href="/account/login?ret=/mobiles/pr%3Fsid%3Dtyy%252F4io%26p%255B%255D%3Dfacets.brand%25255B%25255D%253DApple%26p%255B%255D%3Dfacets.availability%25255B%25255D%253DExclude%252BOut%252Bof%252BStock%26otracker%3Dclp_metro_expandable_1_apple-categ-94e9d_iPhone_apple-products-store_90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite_wp1%26fm%3Dneo%252Fmerchandising%26iid%3DM_4bfdfc9b-d56f-4867-a47e-b028ce8dea24_1.90ff40fd-a46b-4a40-9440-fbe783136afb_DesktopSite%26ppt%3DCLP%26ppn%3DCLP%253Aapple-products-store%26page%3D3">
#              Login &amp; Signup
#             </a>
#            </div>
#           </div>
#           <div class="JvUE0p">
#            <div class="_1jJkOg">
#             <div class="_1jcwFN qt4LQw">
#              <span>
#               More
#              </span>
#             </div>
#             <svg class="_3eosFR" height="8" viewbox="0 0 16 27" width="4.7" xmlns="http://www.w3.org/2000/svg">
#              <path class="_2GxHSA" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#              </path>
#             </svg>
#            </div>
#           </div>
#           <a class="_3NFO0d JvUE0p" href="/viewcart?otracker=Cart_Icon_Click">
#            <div class="_1jJkOg">
#             <svg class="_1-mlum" height="14" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg">
#              <path class="" d="M15.32 2.405H4.887C3 2.405 2.46.805 2.46.805L2.257.21C2.208.085 2.083 0 1.946 0H.336C.1 0-.064.24.024.46l.644 1.945L3.11 9.767c.047.137.175.23.32.23h8.418l-.493 1.958H3.768l.002.003c-.017 0-.033-.003-.05-.003-1.06 0-1.92.86-1.92 1.92s.86 1.92 1.92 1.92c.99 0 1.805-.75 1.91-1.712l5.55.076c.12.922.91 1.636 1.867 1.636 1.04 0 1.885-.844 1.885-1.885 0-.866-.584-1.593-1.38-1.814l2.423-8.832c.12-.433-.206-.86-.655-.86" fill="#fff">
#              </path>
#             </svg>
#             <span>
#              Cart
#             </span>
#            </div>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="_2hlh_L">
#      </div>
#      <div class="zi6sUf">
#       <div class="_3Ed3Ub">
#        <ul class="_114Zhd">
#        </ul>
#       </div>
#      </div>
#     </header>
#     <div style="padding-top:96px">
#      <div class="t-0M7P _2doH3V">
#       <div class="_1VV5Cf _1QHAXj">
#        <div class="_1SFos- _14bj8B" style="transform:scaleX(0)">
#        </div>
#       </div>
#       <div class="_3e7xtJ">
#        <div class="_1HmYoV hCUpcT">
#         <div class="_1HmYoV _35HD7C col-2-12" style="padding:0px 10px 0px 0px">
#          <div class="_1HmYoV _35HD7C col-12-12">
#           <div class="bhgxx2 col-12-12">
#            <div class="_1YuAuf">
#             <section class="xeGmCJ D_NGuZ">
#              <div class="_1iMC4O">
#               <div class="D0YrLF">
#                <span>
#                 Filters
#                </span>
#               </div>
#               <div class="_1oXuet">
#                <span>
#                 Clear all
#                </span>
#               </div>
#              </div>
#              <div class="_37A5dd">
#               <div class="_2xEnNW">
#                <div class="_3clSXm">
#                 <div class="_3TWCND">
#                  ✕
#                 </div>
#                 <div class="_3UZZGt">
#                  Apple
#                 </div>
#                </div>
#                <div class="_3clSXm">
#                 <div class="_3TWCND">
#                  ✕
#                 </div>
#                 <div class="_3UZZGt">
#                  Exclude Out of Stock
#                 </div>
#                </div>
#               </div>
#               <div class="_2Tprpw _386FPC">
#                <span>
#                 Show  more
#                </span>
#               </div>
#              </div>
#             </section>
#             <div class="_1AsMpB">
#              <section class="_3aoPnm">
#               <div class="_1-5MDT">
#                <span>
#                 CATEGORIES
#                </span>
#               </div>
#               <div>
#                <div>
#                 <div class="sUG0yY">
#                  <span>
#                   <svg class="_3OIXYL" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg">
#                    <path class="zTtNVt" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                    </path>
#                   </svg>
#                  </span>
#                  <a class="_3O_Sek _32ZSYo" href="/mobiles-accessories/pr?sid=tyy&amp;p[]=facets.availability%255B%255D%3DExclude%2BOut%2Bof%2BStock&amp;p[]=facets.brand%255B%255D%3DApple&amp;otracker=categorytree" title="Mobiles &amp; Accessories">
#                   Mobiles &amp; Accessories
#                  </a>
#                 </div>
#                </div>
#               </div>
#               <div>
#                <div>
#                 <div class="sUG0yY">
#                  <span>
#                   <svg class="_3OIXYL" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg">
#                    <path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                    </path>
#                   </svg>
#                  </span>
#                  <a class="_3XS1AH _32ZSYo" href="/mobiles/pr?sid=tyy,4io&amp;p[]=facets.availability%255B%255D%3DExclude%2BOut%2Bof%2BStock&amp;p[]=facets.brand%255B%255D%3DApple&amp;otracker=categorytree" title="Mobiles">
#                   Mobiles
#                  </a>
#                 </div>
#                </div>
#               </div>
#              </section>
#             </div>
#             <section class="_1MCcAi D_NGuZ">
#              <div class="_1IqaqM _1iMC4O">
#               <div class="_2Bzspk D0YrLF">
#                <span>
#                 Price
#                </span>
#               </div>
#              </div>
#              <div class="_1zXsFA">
#               <div class="_23Eu_p">
#                <div class="HKK57-" style="height:0;width:0">
#                </div>
#                <div class="HKK57-" style="height:0;width:0">
#                </div>
#                <div class="HKK57-" style="height:0;width:0">
#                </div>
#                <div class="HKK57-" style="height:0;width:0">
#                </div>
#                <div class="HKK57-" style="height:0;width:0">
#                </div>
#                <div class="HKK57-" style="height:0;width:0">
#                </div>
#                <div class="HKK57-" style="height:0;width:0">
#                </div>
#                <div class="HKK57-" style="height:0;width:0">
#                </div>
#               </div>
#              </div>
#              <div class="_1A0dov">
#               <div class="gl5Kwg">
#                <div class="_3G9WVX oVjMho">
#                 <div class="_3aQU3C">
#                 </div>
#                </div>
#                <div class="_3G9WVX _2N3EuE">
#                 <div class="_3aQU3C">
#                 </div>
#                </div>
#                <div class="_3QFE_k">
#                </div>
#                <div class="_3QFE_k _3bwhLT">
#                </div>
#               </div>
#               <div class="UkModz">
#                <div class="_3mWtXv" style="width:undefinedpx">
#                 .
#                </div>
#                <div class="_3mWtXv" style="width:undefinedpx">
#                 .
#                </div>
#                <div class="_3mWtXv" style="width:undefinedpx">
#                 .
#                </div>
#                <div class="_3mWtXv" style="width:undefinedpx">
#                 .
#                </div>
#                <div class="_3mWtXv" style="width:undefinedpx">
#                 .
#                </div>
#                <div class="_3mWtXv" style="width:undefinedpx">
#                 .
#                </div>
#                <div class="_3mWtXv" style="width:undefinedpx">
#                 .
#                </div>
#                <div class="_3mWtXv" style="width:undefinedpx">
#                 .
#                </div>
#                <div class="_3mWtXv" style="width:0px">
#                 .
#                </div>
#               </div>
#              </div>
#              <div class="_3Uy12X">
#               <div class="_1qKb_B">
#                <select class="fPjUPw">
#                 <option class="OMc8Rd" selected="" value="Min">
#                  Min
#                 </option>
#                 <option class="OMc8Rd" value="10000">
#                  ₹10000
#                 </option>
#                 <option class="OMc8Rd" value="13000">
#                  ₹13000
#                 </option>
#                 <option class="OMc8Rd" value="16000">
#                  ₹16000
#                 </option>
#                 <option class="OMc8Rd" value="20000">
#                  ₹20000
#                 </option>
#                 <option class="OMc8Rd" value="25000">
#                  ₹25000
#                 </option>
#                 <option class="OMc8Rd" value="30000">
#                  ₹30000
#                 </option>
#                 <option class="OMc8Rd" value="50000">
#                  ₹50000
#                 </option>
#                </select>
#               </div>
#               <div class="_2LchWD">
#                to
#               </div>
#               <div class="_1YoBfV">
#                <select class="fPjUPw">
#                 <option class="OMc8Rd" value="10000">
#                  ₹10000
#                 </option>
#                 <option class="OMc8Rd" value="13000">
#                  ₹13000
#                 </option>
#                 <option class="OMc8Rd" value="16000">
#                  ₹16000
#                 </option>
#                 <option class="OMc8Rd" value="20000">
#                  ₹20000
#                 </option>
#                 <option class="OMc8Rd" value="25000">
#                  ₹25000
#                 </option>
#                 <option class="OMc8Rd" value="30000">
#                  ₹30000
#                 </option>
#                 <option class="OMc8Rd" value="50000">
#                  ₹50000
#                 </option>
#                 <option class="OMc8Rd" selected="" value="Max">
#                  ₹50000+
#                 </option>
#                </select>
#               </div>
#              </div>
#             </section>
#             <section class="D_NGuZ _1KDdN8">
#              <div class="_2kFyHg _2uXT1C">
#               <label>
#                <input class="_3uUUD5" readonly="" type="checkbox"/>
#                <div class="_1p7h2j">
#                </div>
#                <div class="_1GEhLw">
#                 <div class="_2rIV_l">
#                  <img class="_2rIV_l" height="21" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fa_8b4b59.png"/>
#                 </div>
#                </div>
#               </label>
#              </div>
#              <div class="_20yN1P">
#               <span class="question">
#                ?
#               </span>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                RAM
#               </div>
#               <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#              <div class="_3mk-PQ">
#               <div class="_36jUgy">
#                <div class="_4IiNRh _2mtkou" title="Less than 512 MB">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Less than 512 MB
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="6 GB &amp; Above">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2D7eOw _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     6 GB &amp; Above
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="4 GB">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2D7eOw _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     4 GB
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="3 GB">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2D7eOw _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     3 GB
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="2 GB">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2D7eOw _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     2 GB
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="1 GB">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2D7eOw _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     1 GB
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="512 MB - 1 GB">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2D7eOw _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     512 MB - 1 GB
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Brand
#               </div>
#               <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#              <div class="_3mk-PQ">
#               <div class="_36jUgy">
#                <div class="_2L82nh">
#                 <div class="_2ynhoz">
#                  ✕
#                 </div>
#                 <div class="_1r4irF">
#                  <span>
#                   Clear all
#                  </span>
#                 </div>
#                </div>
#                <div class="-FTLnR">
#                 <svg class="_2oWmkA" height="20" viewbox="0 0 17 18" width="20" xmlns="http://www.w3.org/2000/svg">
#                  <g fill="#2874F1" fill-rule="evenodd">
#                   <path class="_2Re8ik" d="m11.618 9.897l4.225 4.212c.092.092.101.232.02.313l-1.465 1.46c-.081.081-.221.072-.314-.02l-4.216-4.203">
#                   </path>
#                   <path class="_2Re8ik" d="m6.486 10.901c-2.42 0-4.381-1.956-4.381-4.368 0-2.413 1.961-4.369 4.381-4.369 2.42 0 4.381 1.956 4.381 4.369 0 2.413-1.961 4.368-4.381 4.368m0-10.835c-3.582 0-6.486 2.895-6.486 6.467 0 3.572 2.904 6.467 6.486 6.467 3.582 0 6.486-2.895 6.486-6.467 0-3.572-2.904-6.467-6.486-6.467">
#                   </path>
#                  </g>
#                 </svg>
#                 <input class="_3vKPvR" placeholder="Search Brand" type="text" value=""/>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Apple">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input checked="" class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Apple
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Samsung">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Samsung
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Mi">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Mi
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Motorola">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Motorola
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Panasonic">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Panasonic
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Micromax">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Micromax
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="opNt-w _2Tprpw">
#                <span>
#                 205 MORE
#                </span>
#               </div>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Customer Ratings
#               </div>
#               <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#              <div class="_3mk-PQ">
#               <div class="_36jUgy">
#                <div class="_4IiNRh _2mtkou" title="1★ &amp; above">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     1★ &amp; above
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="2★ &amp; above">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     2★ &amp; above
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="3★ &amp; above">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     3★ &amp; above
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="4★ &amp; above">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     4★ &amp; above
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Internal Storage
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Battery Capacity
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Operating System
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Network Type
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Screen Size
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Sim Type
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Primary Camera
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Secondary Camera
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Offers
#               </div>
#               <svg class="_3KyMh7 _2Gnm9R" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#              <div class="_3mk-PQ">
#               <div class="_36jUgy">
#                <div class="_4IiNRh _2mtkou" title="Bank Offer">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Bank Offer
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="No Cost EMI">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     No Cost EMI
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Special Price">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Special Price
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Buy More, Save More">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2D7eOw _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Buy More, Save More
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#                <div class="_4IiNRh _2mtkou" title="Exchange Offer">
#                 <div class="_2wQvxh _1WV8jE">
#                  <div class="_2kFyHg _2D7eOw _2mtkou">
#                   <label>
#                    <input class="_3uUUD5" readonly="" type="checkbox"/>
#                    <div class="_1p7h2j">
#                    </div>
#                    <div class="_1GEhLw">
#                     Exchange Offer
#                    </div>
#                   </label>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Processor Brand
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Speciality
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Resolution Type
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Type
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Operating System Version Name
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Availability
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Clock Speed
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Features
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Number of Cores
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#             <section class="_1gjf4c D_NGuZ">
#              <div class="_3xglSm _1iMC4O">
#               <div class="_2yccxO D0YrLF">
#                Budget
#               </div>
#               <svg class="_3KyMh7" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#                <path class="_1ooUW7" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#                </path>
#               </svg>
#              </div>
#             </section>
#            </div>
#           </div>
#           <div class="bhgxx2 col-12-12">
#            <a class="_2cPh2h" href="/buying-guide/mobiles?sid=tyy,4io&amp;otracker=bg_from_browse_lhs" title="Buying Guide">
#             <div>
#              <span>
#               Need help?
#              </span>
#             </div>
#             <div class="_3OzbwH">
#              <span>
#               Help me decide
#              </span>
#              <svg class="_1fiSL1" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_3fPZ07" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <img alt="Buying Guide" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/buying-guide-illustration_48642c.png"/>
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="_1HmYoV _35HD7C col-10-12">
#          <div class="bhgxx2 col-12-12">
#           <div class="_3UEiDE">
#            <div class="_1joEet">
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/">
#               Home
#              </a>
#              <svg class="_2XP0B_" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_24NaUy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/mobiles-accessories/pr?sid=tyy&amp;marketplace=FLIPKART">
#               Mobiles &amp; Accessories
#              </a>
#              <svg class="_2XP0B_" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#               <path class="_24NaUy" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#               </path>
#              </svg>
#             </div>
#             <div class="_1HEvv0">
#              <a class="_1KHd47" href="/mobiles/pr?sid=tyy,4io&amp;marketplace=FLIPKART">
#               Mobiles
#              </a>
# ...
#             <!-- -->
#             APPLE IPAD MINI 2 PRICE IN INDIA
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/moto-e-2nd-gen-4g-white-8-gb/p/itmeuyd8czsmyydg?otracker=undefined_footer_footer">
#             <!-- -->
#             MOTO E 2ND GEN PRICE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/sony-xperia-c-black-4-gb/p/itmeuyd8fgftgb5z?otracker=undefined_footer_footer">
#             <!-- -->
#             SONY C2305 PRICE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/lenovo-x2-ap-gold-32-gb/p/itmef966ajbgseja?otracker=undefined_footer_footer">
#             <!-- -->
#             LENOVO X2 AP
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/nokia-lumia-630-dual-sim-white-8-gb/p/itme7zdagnncfa8z?otracker=undefined_footer_footer">
#             <!-- -->
#             NOKIA LUMIA 630 DUAL SIM
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/samsung-galaxy-j7-gold-16-gb/p/itmeafbfjhsydbpw?otracker=undefined_footer_footer">
#             <!-- -->
#             J7 SAMSUNG
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/mobiles/android~os/pr?sid=tyy,4io&amp;otracker=undefined_footer_footer">
#             <!-- -->
#             ANDROID MOBILE PRICE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="https://www.flipkart.com/mobiles/~smartphones-under-rs20000/pr?sid=tyy,4io&amp;otracker=undefined_footer_footer">
#             <!-- -->
#             BEST CAMERA SMARTPHONE UNDER 20000
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/q/moto-g4-cases?otracker=undefined_footer_footer">
#             <!-- -->
#             MOTO G4 CASES
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/blackberry-classic-black-16-gb/p/itme3wxuhetumkhx?otracker=undefined_footer_footer">
#             <!-- -->
#             BLACKBERRY CLASSIC INDIA
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/mobiles/touchscreen~feature/pr?sid=tyy,4io&amp;otracker=undefined_footer_footer">
#             <!-- -->
#             SCREEN TOUCH MOBILE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/mobiles/nokia~brand/pr?sid=tyy,4io&amp;otracker=undefined_footer_footer">
#             <!-- -->
#             NOKIA NEW MODEL
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="https://www.flipkart.com/oppo-n1-white-16-gb/p/itmdvfyk84expdjb?otracker=undefined_footer_footer">
#             <!-- -->
#             OPPO N1
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/mobile-accessories/batteries/samsung~brand/pr?sid=tyy,4mr,w65&amp;otracker=undefined_footer_footer">
#             <!-- -->
#             SAMSUNG BATTERY
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/samsung-galaxy-s4-zoom-white-8-gb/p/itmeuyd89g9ycxzg?otracker=undefined_footer_footer">
#             <!-- -->
#             SAMSUNG S4 ZOOM
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/micromax-canvas-5-tan-brown-16-gb/p/itmevt8ypnebfrm7?otracker=undefined_footer_footer">
#             <!-- -->
#             CANVAS 5 PRICE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/lenovo-yoga-3-2-gb-ram-16-8-inch-wi-fi-4g/p/itmefuygsnmuzfgs?otracker=undefined_footer_footer">
#             <!-- -->
#             LENOVO YOGA 8
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/mobile-accessories/power-banks/samsung~brand/pr?sid=tyy,4mr,fu6&amp;otracker=undefined_footer_footer">
#             <!-- -->
#             SAMSUNG POWER BANK
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="https://www.flipkart.com/xolo-era-1x-4g-volte-chocolate-brown-gold-8-gb/p/itmerhq8uhtehukg?otracker=undefined_footer_footer">
#             <!-- -->
#             XOLO ERA 1X 4G PRICE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/q/iphone-7-cases?otracker=undefined_footer_footer">
#             <!-- -->
#             IPHONE 7 CASES
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/sony-xperia-z1-white-16-gb/p/itmeuyd9jnyg2tkx?otracker=undefined_footer_footer">
#             <!-- -->
#             SONY XPERIA Z1 PRICE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="https://www.flipkart.com/mobiles/lemon~brand/pr?sid=tyy,4io&amp;otracker=undefined_footer_footer">
#             <!-- -->
#             LEMON MOBILE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/lenovo-k3-note-black-16-gb/p/itmeuydazkswhfrr?otracker=undefined_footer_footer">
#             <!-- -->
#             LENOVO K 3
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="https://www.flipkart.com/sony-xperia-m-dual-purple-4-gb/p/itmeuyd79ezbh9dg?otracker=undefined_footer_footer">
#             <!-- -->
#             SONY M
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="https://www.flipkart.com/asus-zenfone-4-selfie-rose-pink-32-gb/p/itmexhg3uqhvadhm?otracker=undefined_footer_footer">
#             <!-- -->
#             ASUS ZENFONE 4 SELFIE PRICE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/mobiles/micromax~brand/pr?sid=tyy,4io&amp;otracker=undefined_footer_footer">
#             <!-- -->
#             MICROMAX MOBILE BELOW 5000
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="https://www.flipkart.com/samsung-galaxy-s7-gold-platinum-32-gb/p/itmeuyda4qgqetc6?otracker=undefined_footer_footer">
#             <!-- -->
#             SAMSUNG MOBILE S7 PRICE
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="/apple-iphone-6s-gold-16-gb/p/itmebysga78az3qh?otracker=undefined_footer_footer">
#             <!-- -->
#             IPHONE 6S
#            </a>
#            <a class="_1DLn60 _2vZ4m7" href="https://www.flipkart.com/vivo-y51l-white-16-gb/p/itmefecwzdhaeu8m?otracker=undefined_footer_footer">
#             <!-- -->
#             VIVO Y51L
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="row">
#        <div class="col gu12">
#         <div class="PPB6NR">
#          <h2 class="_1fwBsP">
#           PAYMENT METHOD
#          </h2>
#          <div class="qrCdDp">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="_3niCAn">
#        <div class="row">
#         <div class="col col-6-12">
#          <div class="_-5zFHs">
#           <div class="_1NCIA7">
#            <span>
#             Mail Us:
#            </span>
#           </div>
#           <address class="_3DPJqC">
#            <div class="_3Lv0nZ">
#             <div class="_3aS5mM _3DPJqC">
#              <p>
#               Flipkart Internet Pvt Ltd Block B (Begonia),
#              </p>
#              <p>
#               Ground Floor, Embassy Tech Village,
#              </p>
#              <p>
#               Outer Ring Road, Devarabeesanahalli Village,
#              </p>
#              <p>
#               Varthur Hobli, Bengaluru East Taluk,
#              </p>
#              <p>
#               Bengaluru District,
#              </p>
#              <p>
#               Karnataka, India, 560103.
#              </p>
#             </div>
#            </div>
#           </address>
#          </div>
#         </div>
#         <div class="col col-6-12">
#          <div class="_1Qdplc">
#           <div class="_1NCIA7">
#            <span>
#             Registered Office Address:
#            </span>
#           </div>
#           <address class="_3DPJqC">
#            <div class="_3Lv0nZ">
#             <div class="_3aS5mM _3DPJqC">
#              <p>
#               Flipkart Internet Private Limited,
#              </p>
#              <p>
#               Vaishnavi Summit, Ground Floor, 7th Main,
#              </p>
#              <p>
#               80 Feet Road, 3rd Block,
#              </p>
#              <p>
#               Koramangala,
#              </p>
#              <p>
#               Bengaluru - 560034
#              </p>
#              <p>
#               India
#              </p>
#              <p>
#               CIN : U51109KA2012PTC066107
#              </p>
#              <p>
#               Telephone:
#               <a href="tel:18002089898">
#                1800 208 9898
#               </a>
#              </p>
#             </div>
#            </div>
#           </address>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </footer>
#     <div class="_16c-eX _16DdHx">
#      <div class="kxUxS5">
#       <svg class="j43Uvy" height="27" viewbox="0 0 16 27" width="16" xmlns="http://www.w3.org/2000/svg">
#        <path class="_14b0BE" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff">
#        </path>
#       </svg>
#       <span>
#        Back to top
#       </span>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script nonce="3158612960963832607" type="application/ld+json">
#    {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "url": "http://www.flipkart.com/",
#     "potentialAction": [{
#         "@type": "SearchAction",
#         "target": "http://www.flipkart.com/search?q={search_term_string}",
#         "query-input": "required name=search_term_string"
#         },{
#         "@type": "SearchAction",
#         "target": "android-app://com.flipkart.android/flipkart/de_sq_seg_-search.flipkart.com-_{search_term_string}",
#         "query-input": "required name=search_term_string"
#     }]
# }
#   </script>
#   <script id="is_script" nonce="3158612960963832607">
#    window.__INITIAL_STATE__ = {"abExperiments":{"disablePP":true,"ranking-control":"22Jun","matching-control-25-6":true},"anniversaryPage":{"asyncStatus":"INIT"},"autosuggest":{"query":null,"payloadId":null,"words":{},"asyncStatus":"INIT"},"basket":{"asyncStatus":"INIT","pageLevelError":false},"buyingGuides":{},"cartData":{"asyncStatus":"INIT","pageLevelError":false},"saveForLaterData":{"asyncStatus":"INIT","data":{"requestedStores":[]}},"checkoutPage":{"summary":{"asyncStatus":"INIT"},"checkoutAsyncStatus":"INIT","addressCache":{"newAddressForm":{"id":"newAddressForm","name":"","addressLine1":"","addressLine2":"","landmark":"","city":"","state":"","pincode":"","phone":"","alternatePhone":"","locationTypeTag":""}},"visualState":{"login":"EXPANDED","address":"COLLAPSED","orderSummary":"COLLAPSED","payment":"COLLAPSED"},"loginState":{"asyncStatus":"INIT"},"buyNow":{"eids":"","domain":"physical","analytics":{}},"addressLocation":{"asyncStatus":"INIT"}},"compareAddProductData":{"asyncStatus":"INIT","brandvsproduct":{},"brand":null},"compareBrandData":{"asyncStatus":"INIT"},"comparePageData":{"asyncStatus":"INIT","showDifference":false},"compareWidgetData":[],"config":{"asyncStatus":"SUCCESS","data":{"globalConfig":{"deferReco":true,"degradeImage":false,"disableQuicklinks":false,"disableFDPTracking":false,"disableRecentlyViewed":false,"disableReco":false,"disableReview":false,"disableSearch":false,"disableSearchRetry":false,"disableSeo":false,"enableBbdChanges":false,"offerZoneMorePosition":-1,"searchSummaryBatches":[10,10,20,20],"searchSummaryListBatches":[10,14],"searchSummaryGridBatches":[10,10,20],"enableProductPageServerRendering":true,"enableBrowsePageServerRendering":true,"enableHomePageServerRendering":true,"enableCLPServerRendering":true,"enableStreaming":true,"enableAllReviewsPageServerRendering":true,"saleAddToCartBuyNowEnableTimeout":true,"saleAddToCartBuyNowTimeout":[10,15],"saleAddToCartBuyNowLIDBlacklist":[],"saleAddToCartBuyNowDisable":false,"enableInlineFilters":true,"enablePaymentDegrade":false,"enableYahooPixel":false,"enableCriteo":false,"enableFingerPrint":true,"enableNewYearFlag":false,"skipCTARender":false},"cobrandedExperience":{"yahoo":{"logo":"https://img1a.flixcart.com/www/promos/new/20161121-160909-yahoo-store.png","class":"yahoo-store","store-link":"https://in.yahoo.com/","store-name":"Go Back to Yahoo.in","tracking-name":"yahoocobr","pixel-tracking-url":"https://sp.analytics.yahoo.com/spp.pl?a=10000&.yp=10021645","search-pixel-url":"https://bat.bing.com/action/0?ti=4003414&Ver=2"},"airtel":{"logo":"http://img5a.flixcart.com/www/promos/new/20150618-144245-header-airtel-white.png","class":"airtel-store","store-link":"www.airtel.in","store-name":"Go Back to Airtel.in","tracking-name":"airtel-cobrand-store"},"axis":{"logo":"https://rukminim1.flixcart.com/www/245/50/promos/02/06/2017/4a815cb2-29f5-4c5b-a5af-a9278feb1a1b.png?q=90","class":"axis-store","store-link":"https://www.axisbank.com","store-name":"Go back to Axis Bank","tracking-name":"axiscobr","footer":"Exclusive Store, for Axis Bank Customers!"},"offers":{"logo":"https://img1a.flixcart.com/www/promos/new/20150618-145909-header-smartbuy-white.png","class":"hdfc-store ","store-link":"www.smartbuy.hdfcbank.com","store-name":"Go Back to Smart buy","tracking-name":"hdfc-cobrand-store","footer":"Exclusive store, for HDFC Bank customers!"},"bhaskar":{"logo":"http://img6a.flixcart.com/www/promos/new/20150618-142842-header-logo-bhaskar.png","class":"bhasker-store ","store-link":"www.dainikbhaskar.com","store-name":"Go Back to Dainik Bhaskar","tracking-name":"dainik-cobrand-store"},"itzcash":{"logo":"https://rukminim1.flixcart.com/www/245/50/promos/09/01/2017/c1c2c887-ba6f-4346-9bac-fd98e208bb03.png?q=90","class":"itzcash-store","store-link":"http://itzcash.com","store-name":"Go Back to Itzcash-store","tracking-name":"itzcash-cobrand-store","footer":"Exclusive store, for Itz cash store customers!"},"indusind":{"logo":"https://img1a.flixcart.com/www/promos/ne ...
#   </script>
#   <script nonce="3158612960963832607">
#    window.omniture={tpv:[],tl:[]};window.omniture.trackPageView=function(){window.omniture.tpv.push(arguments)};window.omniture.trackLink=function(){window.omniture.tl.push(arguments)}
#
#     if(window.location.host === 'www.flipkart.com' || /\.store\.flipkart\.com/i.test(window.location.host)){
#         window.s_account = "flipkart-prd"; //omniture account id
#     }else{
#         window.s_account = "flipkart-prd-test";
#     }
#     window.s_isDesktop = true;
#
# 	if ('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") === -1) {
# 		navigator.serviceWorker.register('/sw.js').then(function(registration) {
# 			console.log('ServiceWorker registration successful with scope: ', registration.scope);
# 		})
# 		.catch(function(err) {
# 			console.error('ServiceWorker registration failed: ', err);
# 		});
# 	} else if('serviceWorker' in navigator && navigator.userAgent.indexOf("Mobile") > -1){
#         navigator.serviceWorker.getRegistration().then(function(registration) {
#             var serviceWorkerUnregistered=false;
#             if(registration) {
#                 registration.unregister();
#                 serviceWorkerUnregistered=true;
#             }
#             serviceWorkerUnregistered && window.location.reload();
#         });
#     }
#   </script>
#   <script nonce="3158612960963832607" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/js/raven.3.22.3.js">
#   </script>
#   <script nonce="3158612960963832607">
#    window.Raven && window.Raven.config('https://b2fe488e344a47eda53b8d306edec9b7@sentry.flipkart.com/2',{
# 		release: 'MyAccountsPage.a6576e14.js',
# 		whitelistUrls: [
# 			/flipkart\.com/,
# 			/img1a\.flixcart\.com/
# 		],
# 		ignoreErrors: [
# 			// Random plugins/extensions
# 			'top.GLOBALS',
# 			// See: http://blog.errorception.com/2012/03/tale-of-unfindable-js-error.html
# 			'originalCreateNotification',
# 			'canvas.contentDocument',
# 			'MyApp_RemoveAllHighlights',
# 			'atomicFindClose',
# 			// Facebook borked
# 			'fb_xd_fragment',
# 			// ISP "optimizing" proxy - `Cache-Control: no-transform` seems to reduce this. (thanks @acdha)
# 			// See http://stackoverflow.com/questions/4113268/how-to-stop-javascript-injection-from-vodafone-proxy
# 			'bmi_SafeAddOnload',
# 			'EBCallBackMessageReceived',
# 			'failed to fetch'
# 		],
# 		ignoreUrls: [
# 			// Facebook flakiness
# 			/graph\.facebook\.com/i,
# 			// Facebook blocked
# 			/connect\.facebook\.net\/en_US\/all\.js/i,
# 			// Chrome extensions
# 			/extensions\//i,
# 			/^chrome:\/\//i
# 		],
# 		sanitizeKeys: ['nsid', 'secureToken', 'SN'],
# 		environment: 'production',
# 		sampleRate: 0.5
# 	}).install();
# 	window.Raven && window.Raven.setUserContext({
# 		accountId: ''
# 	});
#   </script>
#   <script async="" defer="" nonce="3158612960963832607" src="//img1a.flixcart.com/www/linchpin/batman-returns/omni/omni16.js">
#   </script>
#  </body>
# </html>

# %%
containers=soup.findAll("div",attrs={"class":"_1-2Iqu row"})

# %%
print(containers[0].prettify())
# Out:
# <div class="_1-2Iqu row">
#  <div class="col col-7-12">
#   <div class="_3wU53n">
#    Apple iPhone 5s (Gold, 16 GB)
#   </div>
#   <div class="niH0FQ">
#    <span class="_2_KrJI" id="productRating_LSTMOBDPPZZDX8WSPATP5HA9O_MOBDPPZZDX8WSPAT_">
#     <div class="hGSR34 _2beYZw">
#      4.3
#      <!-- -->
#      ★
#     </div>
#    </span>
#    <span class="_38sUEc">
#     <span>
#      <span>
#       3,876 Ratings
#      </span>
#      <span class="_1VpSqZ">
#       &amp;
#      </span>
#      <span>
#       679 Reviews
#      </span>
#     </span>
#    </span>
#   </div>
#   <div class="_3ULzGw">
#    <ul class="vFw0gD">
#     <li class="tVe95H">
#      16 GB ROM |
#     </li>
#     <li class="tVe95H">
#      4 inch Retina Display
#     </li>
#     <li class="tVe95H">
#      8MP Rear Camera | 1.2MP Front Camera
#     </li>
#     <li class="tVe95H">
#      Li-Ion Battery
#     </li>
#     <li class="tVe95H">
#      Apple A7 64-bit processor and M7 Motion Co-processor
#     </li>
#     <li class="tVe95H">
#      1 Year for Mobile &amp; Accessories
#     </li>
#    </ul>
#   </div>
#  </div>
#  <div class="col col-5-12 _2o7WAb">
#   <div class="_6BWGkk">
#    <div class="_1uv9Cb">
#     <div class="_1vC4OE _2rQ-NK">
#      ₹23,799
#     </div>
#    </div>
#   </div>
#   <div class="_3MCpsc">
#    EMI starting from
#    <span class="_1JT2XE">
#     ₹
#     <!-- -->
#     791
#     <!-- -->
#     /month
#    </span>
#   </div>
#   <div class="OPF9v4 _2WQngC">
#    <span class="_1xZuAn">
#     Offers
#    </span>
#    <ul class="_3U7997">
#     <li class="_1ZRRx1">
#      Bank Offer
#     </li>
#    </ul>
#   </div>
#  </div>
# </div>

# %%
brand_name=soup.find_all("div",attrs={"class":"_3wU53n"})

# %%
len(brand_name)
# Out:
# 8

# %%
print(brand_name[7].text)
# Out:
# Apple iPhone 8 (Space Grey, 64 GB)

# %%
rating=soup.find_all("div",attrs={"class":"hGSR34 _2beYZw"})

# %%
len(rating)
# Out:
# 8

# %%
rating[7].text
# Out:
# '4.5 ★'

# %%
price=soup.find_all("div",attrs={"class":"_1vC4OE _2rQ-NK"})

# %%
len(price)
# Out:
# 8

# %%
import csv
import pandas as pd

# %%
for container in containers:
  model=container.find_all("div",attrs={"class":"_3wU53n"})
  clean_model=model[0].text
  ratings=container.find_all("div",attrs={"class":"hGSR34 _2beYZw"})
  clean_rating=ratings[0].text
  prices=container.find_all("div",attrs={"class":"_1vC4OE _2rQ-NK"})
  clean_price=prices[0].text
  
  
  final_rating=clean_rating.strip(" ★ ")
  price_split=clean_price.strip(" ₹ ")
  new_price=round(float(str(price_split).replace(",", "")),)
  print(clean_model)
  print(final_rating)
  print(new_price)
  with open('iphone.csv', 'a') as csv_file:
      writer = csv.writer(csv_file)
      writer.writerow([clean_model, final_rating,new_price ])
# Out:
# Apple iPhone 5s (Gold, 16 GB)
# 4.3
# 23799
# Apple iPhone 5s (Gold, 32 GB)
# 3.9
# 22999
# Apple iPhone 6 (Grey, 128 GB)
# 3.9
# 53099
# Apple iPhone SE (Gold, 64 GB)
# 4
# 24800
# Apple iPhone 7 Plus (Black, 256 GB)
# 4.7
# 74000
# Apple iPhone 7 (Rose Gold, 128 GB)
# 4.5
# 57900
# Apple iPhone 7 (Jet Black, 256 GB)
# 4.5
# 60000
# Apple iPhone 8 (Space Grey, 64 GB)
# 4.5
# 63999

# %%
col=["product","rating","price"]

# %%
apple_iphone=pd.read_csv("iphone.csv",header=None,names=col)
print(apple_iphone)
# Out:
#                                product  rating  price
# 0        Apple iPhone 5s (Gold, 16 GB)     4.3  23799
# 1        Apple iPhone 5s (Gold, 32 GB)     3.9  22999
# 2        Apple iPhone 6 (Grey, 128 GB)     3.9  53099
# 3        Apple iPhone SE (Gold, 64 GB)     4.0  24800
# 4  Apple iPhone 7 Plus (Black, 256 GB)     4.7  74000
# 5   Apple iPhone 7 (Rose Gold, 128 GB)     4.5  57900
# 6   Apple iPhone 7 (Jet Black, 256 GB)     4.5  60000
# 7   Apple iPhone 8 (Space Grey, 64 GB)     4.5  63999
